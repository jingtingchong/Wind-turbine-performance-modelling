# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
site = ["A", "B", "C", "D", "E", "F", "G", "H"]
data_all = []

# load the data
# get parent directory
os.chdir("..")
data_directory = 'Data_clean'

for s in site: 
    data_name = s + "_data_clean.csv"
    d = pd.read_csv(os.path.join(os.getcwd(), data_directory, data_name), index_col = 0)
    data_all.append(d)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
data_all
# Out:
# [                         ts  Month  Day  Hour instanceID  Wind_speed  \
#  0       2020-01-01 00:00:00      1    1     0    A_WTG01    3.625675
#  1       2020-01-01 00:00:00      1    1     0    A_WTG02    3.641454
#  3       2020-01-01 00:00:00      1    1     0    A_WTG04    5.191913
#  5       2020-01-01 00:00:00      1    1     0    A_WTG06    2.640701
#  6       2020-01-01 00:10:00      1    1     0    A_WTG01    4.070176
#  ...                     ...    ...  ...   ...        ...         ...
#  316225  2021-01-01 00:00:00      1    1     0    A_WTG02    8.235878
#  316226  2021-01-01 00:00:00      1    1     0    A_WTG03    8.604806
#  316227  2021-01-01 00:00:00      1    1     0    A_WTG04    8.210593
#  316228  2021-01-01 00:00:00      1    1     0    A_WTG05    7.996056
#  316229  2021-01-01 00:00:00      1    1     0    A_WTG06    7.451632
#
#          Wind_speed_sd         TI  Temperature       Power Site
#  0            0.256472   7.073759     1.643807    61.43359    A
#  1            0.538374  14.784600     1.917134    83.51791    A
#  3            0.536756  10.338318     1.985323   170.29570    A
#  5            0.540999  20.486965     2.527086    15.50309    A
#  6            0.300118   7.373585     1.871247   125.96530    A
#  ...               ...        ...          ...         ...  ...
#  316225       0.904783  10.985867     3.882621  1103.88800    A
#  316226       1.015870  11.805844     3.714342  1244.68500    A
#  316227       1.079385  13.146249     3.508555  1164.59800    A
#  316228       0.781768   9.776918     3.689026   923.51930    A
#  316229       0.991213  13.301953     3.747645   908.41480    A
#
#  [244026 rows x 11 columns],
#                           ts  Month  Day  Hour instanceID  Wind_speed  \
#  0       2020-01-01 00:00:00      1    1     0    B_WTG01    5.095141
#  1       2020-01-01 00:00:00      1    1     0    B_WTG02    5.087110
#  2       2020-01-01 00:00:00      1    1     0    B_WTG03    7.328426
#  3       2020-01-01 00:00:00      1    1     0    B_WTG04    7.127246
#  4       2020-01-01 00:00:00      1    1     0    B_WTG05    7.359853
#  ...                     ...    ...  ...   ...        ...         ...
#  474340  2021-01-01 00:00:00      1    1     0    B_WTG05    5.275089
#  474341  2021-01-01 00:00:00      1    1     0    B_WTG06    5.377703
#  474342  2021-01-01 00:00:00      1    1     0    B_WTG07    4.329758
#  474343  2021-01-01 00:00:00      1    1     0    B_WTG08    6.097418
#  474344  2021-01-01 00:00:00      1    1     0    B_WTG09    5.742271
#
#          Wind_speed_sd         TI  Temperature       Power Site
#  0            0.693535  13.611685     2.929167  348.153622    B
#  1            0.555204  10.913946     2.992500  374.113193    B
#  2            0.606349   8.273928     2.970833  815.915979    B
#  3            0.528469   7.414767     2.832500  867.836771    B
#  4            0.601081   8.167022     3.052500  744.700635    B
#  ...               ...        ...          ...         ...  ...
#  474340       1.186871  22.499540     6.198333  387.274779    B
#  474341       1.146455  21.318671     5.742500  396.324043    B
#  474342       0.799989  18.476535     5.801667  210.556521    B
#  474343       1.084794  17.791033     5.692500  463.653817    B
#  474344       0.927885  16.158845     5.545833  389.103549    B
#
#  [328252 rows x 11 columns],
#                            ts  Month  Day  Hour instanceID  Wind_speed  \
#  3        2020-01-01 00:00:00      1    1     0    C_WTG04    4.695373
#  4        2020-01-01 00:00:00      1    1     0    C_WTG05    3.614577
#  5        2020-01-01 00:00:00      1    1     0    C_WTG06    3.526409
#  6        2020-01-01 00:00:00      1    1     0    C_WTG07    4.067837
#  7        2020-01-01 00:00:00      1    1     0    C_WTG08    4.145381
#  ...                      ...    ...  ...   ...        ...         ...
#  1106518  2020-12-31 21:50:00     12   31    21    C_WTG08    3.462383
#  1106602  2020-12-31 22:30:00     12   31    22    C_WTG08    6.659352
#  1106623  2020-12-31 22:40:00     12   31    22    C_WTG08    4.604579
#  1106707  2020-12-31 23:20:00     12   31    23    C_WTG08    4.924803
#  1106728  2020-12-31 23:30:00     12   31    23    C_WTG08    3.770926
#
#           Wind_speed_sd         TI  Temperature       Power Site
#  3             0.712574  15.176091     5.270000  160.230282    C
#  4             0.569317  15.750575     5.451667   64.632802    C
#  5             0.681956  19.338555     5.393333   65.132216    C
#  6             0.638995  15.708470     5.593333  100.370317    C
#  7             0.684033  16.501090     6.593333  137.044755    C
#  ...                ...        ...          ...         ...  ...
#  1106518       0.802970  23.191250     5.073333   43.471178    C
#  1106602       1.027965  15.436412     5.024138  591.429897    C
#  1106623       1.572165  34.143509     5.223333  233.237044    C
#  1106707       0.711829  14.453960     5.158621  193.766015    C
#  1106728       0.712301  18.889287     5.078333   94.648381    C
#
#  [703172 rows x 11 columns],
#                           ts  Month  Day  Hour instanceID  Wind_speed  \
#  5       2020-01-01 00:00:00      1    1     0    D_WTG06      3.2985
#  6       2020-01-01 00:00:00      1    1     0    D_WTG07      2.9335
#  9       2020-01-01 00:00:00      1    1     0    D_WTG10      2.5060
#  20      2020-01-01 00:10:00      1    1     0    D_WTG05      3.5740
#  21      2020-01-01 00:10:00      1    1     0    D_WTG06      3.5935
#  ...                     ...    ...  ...   ...        ...         ...
#  843275  2021-01-01 00:00:00      1    1     0    D_WTG12      8.5150
#  843276  2021-01-01 00:00:00      1    1     0    D_WTG13      8.7210
#  843277  2021-01-01 00:00:00      1    1     0    D_WTG14      5.5675
#  843278  2021-01-01 00:00:00      1    1     0    D_WTG15      8.6745
#  843279  2021-01-01 00:00:00      1    1     0    D_WTG16      8.3205
#
#          Wind_speed_sd         TI  Temperature   Power Site
#  5            0.305504   9.261910          4.0   21.55    D
#  6            0.470928  16.053436          4.0   18.80    D
#  9            0.427603  17.063153          4.0    2.70    D
#  20           0.322481   9.022972          4.0   32.05    D
#  21           0.339607   9.450585          4.0   51.25    D
#  ...               ...        ...          ...     ...  ...
#  843275       1.270927  14.925741          2.0  897.95    D
#  843276       1.090454  12.503768          2.0  887.50    D
#  843277       0.774241  13.906435          2.0  352.35    D
#  843278       0.510896   5.889631          2.0  985.90    D
#  843279       0.808508   9.717057          2.0  849.25    D
#
#  [610571 rows x 11 columns],
#                           ts  Month  Day  Hour instanceID  Wind_speed  \
#  0       2020-01-01 00:00:00      1    1     0    E_WTG01         6.2
#  1       2020-01-01 00:00:00      1    1     0    E_WTG02         5.8
#  2       2020-01-01 00:00:00      1    1     0    E_WTG03         5.9
#  3       2020-01-01 00:10:00      1    1     0    E_WTG01         5.7
#  4       2020-01-01 00:10:00      1    1     0    E_WTG02         5.6
#  ...                     ...    ...  ...   ...        ...         ...
#  158110  2020-12-31 23:50:00     12   31    23    E_WTG02         8.9
#  158111  2020-12-31 23:50:00     12   31    23    E_WTG03         8.6
#  158112  2021-01-01 00:00:00      1    1     0    E_WTG01         8.7
#  158113  2021-01-01 00:00:00      1    1     0    E_WTG02         8.8
#  158114  2021-01-01 00:00:00      1    1     0    E_WTG03         8.2
#
#          Wind_speed_sd  TI  Temperature  Power Site
#  0                 NaN NaN          6.0  236.0    E
#  1                 NaN NaN          5.0  275.0    E
#  2                 NaN NaN          2.0  279.0    E
#  3                 NaN NaN          6.0  269.0    E
#  4                 NaN NaN          4.9  224.0    E
#  ...               ...  ..          ...    ...  ...
#  158110            NaN NaN          7.0  791.0    E
#  158111            NaN NaN          6.0  744.0    E
#  158112            NaN NaN          8.0  838.0    E
#  158113            NaN NaN          7.0  757.0    E
#  158114            NaN NaN          6.0  662.0    E
#
#  [142612 rows x 11 columns],
#                            ts  Month  Day  Hour instanceID  Wind_speed  \
#  4        2020-01-01 00:00:00      1    1     0    F_WTG05    3.941197
#  10       2020-01-01 00:00:00      1    1     0    F_WTG14    6.037713
#  13       2020-01-01 00:00:00      1    1     0    F_WTG17    6.678194
#  14       2020-01-01 00:00:00      1    1     0    F_WTG18    7.063394
#  15       2020-01-01 00:00:00      1    1     0    F_WTG19    6.718910
#  ...                      ...    ...  ...   ...        ...         ...
#  1106800  2021-01-01 00:00:00      1    1     0    F_WTG20    5.557047
#  1106801  2021-01-01 00:00:00      1    1     0    F_WTG21    5.925056
#  1106802  2021-01-01 00:00:00      1    1     0    F_WTG22    6.454437
#  1106803  2021-01-01 00:00:00      1    1     0    F_WTG23    5.521681
#  1106804  2021-01-01 00:00:00      1    1     0    F_WTG24    6.150678
#
#           Wind_speed_sd         TI  Temperature       Power Site
#  4             0.785721  19.936101     7.254701  106.885468    F
#  10            0.798456  13.224478     6.998294  331.184296    F
#  13            0.920065  13.777153     7.000000  416.412262    F
#  14            0.681976   9.655075     7.000000  503.765381    F
#  15            0.544253   8.100316     6.000000  459.650757    F
#  ...                ...        ...          ...         ...  ...
#  1106800       0.793355  14.276557     4.000000  254.234894    F
#  1106801       1.006598  16.988835     4.004515  405.478546    F
#  1106802       0.950442  14.725406     4.947099  511.448792    F
#  1106803       1.145839  20.751634     4.000000  364.554626    F
#  1106804       1.259837  20.482896     4.827119  382.591522    F
#
#  [731327 rows x 11 columns],
#                            ts  Month  Day  Hour instanceID  Wind_speed  \
#  0        2020-01-01 00:00:00      1    1     0   G_WTGA01         4.4
#  1        2020-01-01 00:00:00      1    1     0   G_WTGA02         5.0
#  2        2020-01-01 00:00:00      1    1     0   G_WTGA03         5.0
#  3        2020-01-01 00:00:00      1    1     0   G_WTGA04         4.5
#  4        2020-01-01 00:00:00      1    1     0   G_WTGA05         5.0
#  ...                      ...    ...  ...   ...        ...         ...
#  2951473  2021-01-01 00:00:00      1    1     0   G_WTGB22         3.6
#  2951474  2021-01-01 00:00:00      1    1     0   G_WTGB23         3.0
#  2951475  2021-01-01 00:00:00      1    1     0   G_WTGB24         2.6
#  2951477  2021-01-01 00:00:00      1    1     0   G_WTGB26         3.0
#  2951479  2021-01-01 00:00:00      1    1     0   G_WTGB28         3.5
#
#           Wind_speed_sd         TI  Temperature      Power Site
#  0                 0.84  19.090908         22.0  36.099998    G
#  1                 1.18  23.599999          6.0  51.000000    G
#  2                 0.55  11.000000          8.0  39.400002    G
#  3                 0.89  19.777777          3.0  40.700001    G
#  4                 1.14  22.800000          6.0  49.200001    G
#  ...                ...        ...          ...        ...  ...
#  2951473           0.45  12.500000          2.0   8.400000    G
#  2951474           0.77  25.666666          1.0  13.000000    G
#  2951475           0.63  24.230770          1.0   6.200000    G
#  2951477           0.77  25.666666          1.0   7.000000    G
#  2951479           0.95  27.142857          2.0  12.300000    G
#
#  [2189049 rows x 11 columns],
#                            ts  Month  Day  Hour instanceID  Wind_speed  \
#  0        2020-01-01 00:00:00      1    1     0    H_WTG01         4.1
#  1        2020-01-01 00:00:00      1    1     0    H_WTG02         3.9
#  5        2020-01-01 00:00:00      1    1     0    H_WTG06         3.7
#  6        2020-01-01 00:00:00      1    1     0    H_WTG07         5.3
#  7        2020-01-01 00:00:00      1    1     0    H_WTG08         4.5
#  ...                      ...    ...  ...   ...        ...         ...
#  1159448  2020-12-31 23:40:00     12   31    23    H_WTG05         3.4
#  1159458  2020-12-31 23:40:00     12   31    23    H_WTG15         3.7
#  1159468  2020-12-31 23:50:00     12   31    23    H_WTG03         4.1
#  1159480  2020-12-31 23:50:00     12   31    23    H_WTG15         2.9
#  1159502  2021-01-01 00:00:00      1    1     0    H_WTG15         2.3
#
#           Wind_speed_sd         TI  Temperature  Power Site
#  0                 0.45  10.975610         18.0    2.0    H
#  1                 0.95  24.358973         12.0    3.0    H
#  5                 0.63  17.027027         14.0    2.0    H
#  6                 0.63  11.886792         11.0   41.0    H
#  7                 0.84  18.666666         10.0   23.0    H
#  ...                ...        ...          ...    ...  ...
#  1159448           0.45  13.235293          6.0    3.0    H
#  1159458           0.89  24.054053          3.0   31.0    H
#  1159468           0.77  18.780488          7.0    1.0    H
#  1159480           0.71  24.482757          3.0   16.0    H
#  1159502           0.32  13.913043          3.0    7.0    H
#
#  [781278 rows x 11 columns]]

# %%
# %%time
# Plot power curve for each turbine
plt.rc('font', size=14) 

fig, ax = plt.subplots(2,4, figsize=(16,8), sharex='col', sharey='row');

i = 0
for r in range (2):
        for c in range (4):
            data_turbine = data_all[i]
            sns.scatterplot(x = data_turbine['Wind_speed'], y = data_turbine['Power'], ax = ax[r][c], s = 1, edgecolor = None)
            ax[r][c].set_title(site[i])
            ax[r][c].set_xlabel("Wind speed, m/s") 
            ax[r][c].set_ylabel("Power, kW") 
            i += 1
plt.show()
# Out:
# Wall time: 4.12 s

# %%
# assign site name in the dataframe
i = 0

for s in site: 
    data_all[i] = data_all[i].assign(Site = s)
    i += 1

# %%
# combine data frames
data_all_combined = pd.DataFrame()
for i in range (len(site)):
    if data_all_combined.empty: 
        data_all_combined = data_all[i]
    else:
        data_all_combined = pd.concat([data_all_combined, data_all[i]])

# %%
data_all_combined
# Out:
#                           ts  Month  Day  Hour instanceID  Wind_speed  \
# 0        2020-01-01 00:00:00      1    1     0    A_WTG01    3.625675
# 1        2020-01-01 00:00:00      1    1     0    A_WTG02    3.641454
# 3        2020-01-01 00:00:00      1    1     0    A_WTG04    5.191913
# 5        2020-01-01 00:00:00      1    1     0    A_WTG06    2.640701
# 6        2020-01-01 00:10:00      1    1     0    A_WTG01    4.070176
# ...                      ...    ...  ...   ...        ...         ...
# 1159448  2020-12-31 23:40:00     12   31    23    H_WTG05    3.400000
# 1159458  2020-12-31 23:40:00     12   31    23    H_WTG15    3.700000
# 1159468  2020-12-31 23:50:00     12   31    23    H_WTG03    4.100000
# 1159480  2020-12-31 23:50:00     12   31    23    H_WTG15    2.900000
# 1159502  2021-01-01 00:00:00      1    1     0    H_WTG15    2.300000
#
#          Wind_speed_sd         TI  Temperature      Power Site
# 0             0.256472   7.073759     1.643807   61.43359    A
# 1             0.538374  14.784600     1.917134   83.51791    A
# 3             0.536756  10.338318     1.985323  170.29570    A
# 5             0.540999  20.486965     2.527086   15.50309    A
# 6             0.300118   7.373585     1.871247  125.96530    A
# ...                ...        ...          ...        ...  ...
# 1159448       0.450000  13.235293     6.000000    3.00000    H
# 1159458       0.890000  24.054053     3.000000   31.00000    H
# 1159468       0.770000  18.780488     7.000000    1.00000    H
# 1159480       0.710000  24.482757     3.000000   16.00000    H
# 1159502       0.320000  13.913043     3.000000    7.00000    H
#
# [5730287 rows x 11 columns]

# %%
# %%time 

# Make boxplot
fig, ax = plt.subplots(2, 2, figsize = (16, 10))

features = [ 'Power','Wind_speed', 'TI','Temperature']
features_name = [ 'Power, kW','Wind speed, m/s', 'TI, %','Ambient temperature, °C']

i = 0
for r in range (2):
    for c in range (2):
        sns.boxplot( data = data_all_combined, y = features[i], x = 'Site', orient = 'v', ax = ax[c][r], palette = "husl")
        ax[c][r].set(ylabel = features_name[i], xlabel = 'Site code')
        i += 1

plt.show()
# Out:
# Wall time: 9.27 s

# %%
# %%time 

# Make violin plot
plt.rc('font', size=14) 
fig, ax = plt.subplots(2, 2, figsize = (16, 10))

features = [ 'Power','Wind_speed', 'TI','Temperature']
features_name = [ 'Power, kW','Wind speed, m/s', 'TI, %','Ambient temperature, °C']

i = 0
for r in range (2):
    for c in range (2):
        sns.violinplot( data = data_all_combined, y = features[i], x = 'Site', orient = 'v', ax = ax[c][r])
        ax[c][r].set(xlabel = features_name[i], ylabel = 'Site code')
        i += 1

plt.show()
# Out:
# Wall time: 1min 14s
